# %% [markdown]
# ![En tête general](https://raw.githubusercontent.com/PythonLycee/PyLyc/master/img/En_tete_general.png)
#
#
# <i>© Copyright Franck CHEVRIER 2019-2023 https://www.python-lycee.com.</i><br>
# <i>Activité réalisée en collaboration avec Carole BOURGON.</i><br>
# <i>Les activités partagées sur <a href="https://capytale2.ac-paris.fr/web/accueil"><strong>Capytale</strong></a> sont sous licence <a href="https://creativecommons.org/licenses/by-sa/3.0/fr/">Creative Commons</a>.</i>
#
# <span style="color: #9317B4"> Pour exécuter une saisie Python, sélectionner la cellule et valider avec </span><span style="color: #B317B4"><strong>SHIFT+Entrée</strong></span>.

# %% [markdown]
# <h1 style="color:#0E2C98; font-size:44px">Illustration du principe d'inertie <span style="color:red;">(Corrigé)</span></h1>

# %% [markdown]
# ### <span style="color:#031E7F">Sommaire</span>
#
# <span style="color:#222222">1.</span> <a href="#1">Mouvement d'un mobile sur coussin d'air</a><br>
# <span style="color:#222222">2.</span> <a href="#2">Chute d'une balle</a><br>

# %% [markdown]
# <span id="1"></span>
# <h3 style="color:#1333A8; font-size:28px">1. Mouvement d'un mobile sur coussin d'air</h3>

# %% [markdown]
# <figure style="float: right; padding-left: 20px;">
#     <video controls src="https://raw.githubusercontent.com/PythonLycee/PyLyc/master/video/Mobile_sans_son.mp4" width="480" height="270" />
# </figure>
# <p style="text-align:justify;">
# Nous avons filmé le mouvement d’un mobile autoporteur sur une table horizontale après lui avoir donné une légère impulsion. Le mobile est doté d’un dispositif injectant de l’air par le dessous limitant ainsi très fortement les frottements avec la table.
# <br><br>Le centre du mobile est matérialisé par un point noir sur un carré jaune. C’est ce point que nous allons étudier.
# </p>
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
# <ul>
#     <li><strong>Question 1.1. </strong><br>Visionner la vidéo puis indiquer le système et le référentiel de cette étude.<br>Faire une hypothèse sur le mouvement du mobile.<br></li>
#     </ul>
#     </BLOCKQUOTE>

# %% [raw]
# Écrire votre réponse ici (question 1.1)

# %% [markdown]
# <strong style="color:red">1.1. Le système étudié est le mobile autoporteur. Son mouvement est étudié dans le référentiel terrestre.<br>
# $\quad\;$Le mobile semble se déplacer en ligne droite à vitesse constante.<br>
# $\quad\;$On peut faire l'hypothèse que le mouvement du mobile est rectiligne et uniforme. </strong>

# %% [markdown]
#
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
# <ul>
# <figure style="float: right; padding-left: 20px; padding-right: 20px; background-color:#FFFFFF"><br>
# <img src="https://raw.githubusercontent.com/PythonLycee/PyLyc/master/img/Schema_mobile.gif" style="width:100px;"/><br>
#     </figure>
#     <li><strong>Question 1.2. </strong><br><br><strong>a.</strong>Réaliser un schéma du mobile.<br>$\;\;\;$Nommer puis dessiner les <strong>deux forces</strong> qui s’exercent sur le mobile <strong>lorsqu'il est immobile</strong>.<br><br>
#         <strong>b.</strong> Réaliser un schéma du mobile.<br>$\;\;\;$Nommer puis dessiner les <strong>trois forces</strong> qui s’exercent sur le mobile <strong>au moment de l’impulsion</strong>.<br><br><strong>c.</strong> Réaliser un schéma du mobile.<br>$\;\;\;$Nommer puis dessiner les <strong>deux forces</strong> qui s’exercent sur le mobile <strong>lors de son mouvement</strong>.<br>$\;\;\;$Calculer l'intensité de ces deux forces.
#         <BLOCKQUOTE style="background-color:#EFF2FE;">
#         Données :
#         <ul>
#             <li>Intensité de la pesanteur : $g=9,81 \; \text{N}\cdot\text{kg}^{-1}$</li>
#             <li>Voir les indications sur le mobile (conseil : mettre la vidéo en plein écran).</li>
#         </ul>
#         </BLOCKQUOTE>
#         <strong>d.</strong> Préciser pour chacun des trois cas, si les forces se compensent ou pas.
#  </li>
# </ul>
# </BLOCKQUOTE>

# %% [raw]
# Écrire vos réponses ici (question 1.2)

# %% [markdown]
# <strong style="color:red">1.2.<br><br>
# a. Les forces s'exerçant sur le mobile lorsqu'il est immobile sont :
# <ul>
#     <img src="https://raw.githubusercontent.com/PythonLycee/PyLyc/master/img/mob_corr_schema_1.png" style="float:right; "/>
#     <li>le poids P ;</li>
#     <li>la réaction du support R.</li>
# </ul>
# <br><br>
# b. Les forces s'exerçant sur le mobile lors de l'impulsion sont :
# <ul>
#     <img src="https://raw.githubusercontent.com/PythonLycee/PyLyc/master/img/mob_corr_schema_2.png" style="float:right; "/>
#     <li>le poids P ;</li>
#     <li>la réaction du support R ;</li>
#     <li>la force de poussée exercée par la main F.</li>
# </ul>
# <br><br>
# c. Les forces s'exerçant sur le mobile lors de son mouvement sont :
# <ul>
#     <img src="https://raw.githubusercontent.com/PythonLycee/PyLyc/master/img/mob_corr_schema_1.png" style="float:right; "/>
#     <li>le poids P ;</li>
#     <li> la réaction du support R.</li>
# </ul>
# $\text{P} = \text{m}\times\text{g} = 598\cdot10^{-3}\cdot9,81 = 5,9 \;\text{N}$.<br>
# D'après le principe de l'action et de la réaction : $\text{R} = \text{P} = 5,9 \;\text{N}$.
# <br><br>
# d. Les forces se compensent uniquement dans le premier cas et le troisième cas.
# </strong>

# %% [markdown]
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
# <ul>
#     <li><strong>Question 1.3. </strong><br>Exécuter la cellule ci-dessous et suivre les indications pour réaliser un pointage du centre du mobile pendant son déplacement.</li>
# </ul>
# </BLOCKQUOTE>

# %%
# Exécuter cette cellule (SHIFT+Entrée)
from IPython.display import HTML ; HTML("""<iframe scrolling="no" title="Mobile_mvt" src="https://www.geogebra.org/material/iframe/id/m6bky2jd/width/1084/height/599/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" width="980" height="520px" style="border:0px;"> </iframe>""")

# %% [markdown]
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
# <ul>
#     <li><strong>Question 1.4. </strong><br>
#         <strong>a.</strong> En observant le pointage réalisé, caractériser à l'aide de deux adjectifs le mouvement du mobile.<br>
#     <strong>b.</strong> Comparer les valeurs obtenues à celles de votre binôme. Indiquer si les mesures obtenues sont précises.<br>
#         <strong>c.</strong> À l'aide du pointage, compléter les listes <mark style="font-family: Consolas; background-color:#CAD4FC;">x</mark> et <mark style="font-family: Consolas; background-color:#CAD4FC;">y</mark> suivantes avec les coordonnées des points $\text{M}_1$, $\text{M}_2$, $\text{M}_3$... et exécuter ensuite cette cellule pour stocker ces listes en mémoire.
# <br><br>
# Aide : En langage Python, les virgules des nombres décimaux s'écrivent avec des points, et on sépare les nombres par des virgules.</li>
# </ul>
# </BLOCKQUOTE>

# %% [raw]
# Écrire vos réponses ici (questions1.4.a et 1.4.b)

# %% [markdown]
# <strong style="color:red">1.4.<br><br>
# a. Le mouvement du mobile est rectiligne et uniforme.<br><br>
# b. On constate pour le pointage un très léger décalage entre les valeurs. Les valeurs obtenues ne sont pas des valeurs exactes, elles sont entachées d'une certaine incertitude. Néanmoins les résultats restent relativement précis à +ou- 0,2 cm.
# </strong>

# %%
# abscisses du mobile (exprimées en cm)
x = [ 10.3 , 15.3 , 20.5 , 25.5 , 30.3 , 35.3 , 40.2 , 45.1 , 49.9 , 54.8 , 59.7 , 64.3 , 69.2 , 73.9 , 78.4 ] 

# ordonnées du mobile (exprimées en cm)
y = [ 40.4 , 38.8 , 37.3 , 35.7 , 34.4 , 32.8 , 31.3 , 29.8 , 28.4 , 26.9 , 25.5 , 24.0 , 22.5 , 21.1 , 19.7 ] 

# intervalle de temps entre deux prises de vue (exprimé en s)
Dt = 0.1

# %% [markdown]
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
# <ul>
#     <li><strong>Question 1.5. </strong><br>
# Exécuter la cellule suivante, qui calcule les distances $\text{M}_i\text{M}_{i+1}$.<br>
# À partir des résultats obtenus, indiquer quelle caractéristique du mouvement du mobile est mise en évidence.
#     </li></ul>
# </BLOCKQUOTE>

# %%
# Exécuter cette cellule (SHIFT+Entrée)
from math import sqrt

def distance(x,y):
    "fonction qui calcule les distances à partir des listes d'abscisses et d'ordonnées"
    return [ round ( sqrt( (x[i+1]-x[i])**2 + (y[i+1]-y[i])**2 ) ,1) for i in range(len(x)-1) ]

distance(x,y)

# %% [raw]
# Écrire votre réponse ici (question 1.5)

# %% [markdown]
# <strong style="color:red">1.5.<br><br>On observe que la distance $\text{M}_i\text{M}_{i+1}$ est quasiment constante aux incertitudes de mesure près. La distance parcourue par le mobile en $0,1$ s est toujours la même. Le mobile se déplace à vitesse constante. Le mouvement est donc uniforme.
# </strong>

# %% [markdown]
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
# <ul>
#     <li><strong>Question 1.6. </strong><br>Pour chaque point $\text{M}_i(x_i;y_i)$, on fait l'estimation que les coordonnées du vecteur vitesse $\vec{v_i}$ vérifient :<br><br>
# <font size="3"> $\displaystyle \left( \vec{v_i} \right)_x = \frac{x_{i+1}-x_i}{Δt}$ </font> $\;$ et $\;$
# <font size="3"> $\displaystyle \left( \vec{v_i} \right)_y = \frac{y_{i+1}-y_i}{Δt}$ </font>.
# <br><br>
# On a défini ci-dessous une liste Python <mark style="font-family: Consolas; background-color:#CAD4FC;">vx</mark> contenant les abscisses de ces vecteurs.<br>
# Définir de la même façon la liste Python <mark style="font-family: Consolas; background-color:#CAD4FC;">vy</mark> contenant leurs ordonnées.<br><br>Note : la syntaxe Python <mark style="font-family: Consolas; background-color:#CAD4FC;">round( ,1)</mark> permet d'obtenir des valeurs approchées au dixième près.
# </li>
# </ul>
# </BLOCKQUOTE>

# %%
# liste des abscisses des vecteurs vitesse
vx = [ round ( (x[i+1]-x[i])/Dt ,1 ) for i in range(len(x)-1) ]

# liste des ordonnées des vecteurs vitesse (à créer)
vy = [ round ( (y[i+1]-y[i])/Dt ,1 ) for i in range(len(y)-1) ]

# affichage des listes
vx,vy

# %% [markdown]
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
# <ul>
#     <li><strong>Question 1.7. </strong><br>La fonction Python <mark style="font-family: Consolas; background-color:#CAD4FC;">Graph_Pointage</mark> ci-dessous permet d'obtenir le tracé des <span style="color: #0000FF">vecteurs vitesse</span> pour le <span style="color: #FF0000">pointage</span> effectué.<br>Exécuter cette cellule et la suivante pour obtenir le graphique.</li></ul>
# </BLOCKQUOTE>

# %%
# Exécuter cette cellule (SHIFT+Entrée)
import matplotlib.pyplot as plt

def Graph_Pointage(x,y,vx,vy,zoom_v=20,titre="Trajectoire du mobile",nb_fig=1):
    "Fonction représentant le pointage avec affichage des vecteurs vitesses"
     
    #initialisation du graphique et génération des légendes
    plt.figure(nb_fig)
    plt.clf()
    plt.title(titre)
    plt.xlabel("abscisse en cm",fontsize=8)
    plt.ylabel("ordonnée en cm",fontsize=8)    
    plt.arrow(0,0,10,0,head_width=2, head_length=0.5, fc='lightblue', ec='blue')
    plt.text(0,1,"unité de\nvitesses\n$"+str(10*zoom_v)+"\;cm\cdot s^{-1}$",fontsize=8)    
    
    # représentation des points
    plt.scatter(x,y,color='red') 
    
    # représentation des vecteurs vitesse
    for i in range(len(vx)):
        plt.arrow( x[i] , y[i] , vx[i]/zoom_v , vy[i]/zoom_v , head_width=0.5, head_length=1, fc='lightblue', ec='blue')
    
    # affichage
    plt.show()

# %%
# Exécuter cette cellule (SHIFT+Entrée)
Graph_Pointage(x,y,vx,vy)

# %% [markdown]
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
# <ul>
#     <li><strong>Question 1.8. </strong><br>À l'aide du graphique, conclure sur le mouvement du mobile.
#         </li></ul>
# </BLOCKQUOTE>

# %% [raw]
# Écrire votre réponse ici (question 1.8)

# %% [markdown]
# <strong style="color:red">1.8.<br><br>
# On observe que les points de la trajectoire sont alignés et à égale distance. Le mouvement du mobile est uniforme et rectiligne. </strong>

# %% [markdown]
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
# <figure style="float: right; max-width:15%;">
#     <img src="https://raw.githubusercontent.com/PythonLycee/PyLyc/master/img/Isaac_Newton.jpg">
#     <figcaption style="text-align: center; font-size: 10px;"><a href="https://fr.wikipedia.org/wiki/Isaac_Newton">Isaac Newton (1643-1727)</a></figcaption>
# </figure>
#     <ul>
#         <li><strong>Question 1.9. </strong><br><br>Dans son ouvrage <a href="https://gallica.bnf.fr/ark:/12148/bpt6k3363w.image"><i>Principia Mathematica</i></a> publié en 1687, Isaac Newton énonce trois lois.<br> La première loi fait référence au principe d’inertie :<br>
#             <img src="https://raw.githubusercontent.com/PythonLycee/PyLyc/master/img/Loi1_Newton_transp.png">
#             <br> <BLOCKQUOTE style="background-color:#EFF2FE;">« <strong>Tout corps persévère dans son état de repos ou de mouvement rectiligne uniforme si les forces qui s’exercent sur lui se compensent.</strong> »</BLOCKQUOTE>
#             La contraposée du principe d'inertie s'écrit :
# <BLOCKQUOTE style="background-color:#EFF2FE;">
# « <strong>Si les forces qui s’exercent sur un système ne se compensent pas alors le système n’est ni immobile, ni en mouvement rectiligne et uniforme.</strong> »
# </BLOCKQUOTE>
# <br>
# <strong>a.</strong> Indiquer en justifiant si le principe d’inertie est vérifié dans le cas du mobile autoporteur <strong>lorsqu'il est immobile</strong>.<br><br><strong>b.</strong> Indiquer en justifiant si le principe d’inertie est vérifié dans le cas du mobile autoporteur <strong>lors de l'impulsion</strong>.<br><br><strong>c.</strong> Indiquer en justifiant si le principe d’inertie est vérifié dans le cas du mobile autoporteur <strong>après l'impulsion</strong>.</li></ul>
# </BLOCKQUOTE>

# %% [raw]
# Écrire votre réponse ici (question 1.9)

# %% [markdown]
# <strong style="color:red">1.9.<br><br>
# a. lorsqu'il est immobile, les forces qui s'exercent sur le mobile se compensent ($\text{P} = \text{R}$). Le principe d'inertie est vérifié dans le cas du mobile.<br><br>
# b. Au moment de l'impulsion, les forces qui s'exercent sur le mobile ne se compensent pas. Le mouvement n'est pas uniforme, et le principe d'inertie est vérifié (cela correspond à la contraposée du principe d'inertie).<br><br>
# c. Après l'impulsion, les forces qui s'exercent sur le mobile se compensent ($\text{P} = \text{R}$). On observe un mouvement rectiligne et uniforme. Le principe d'inertie est vérifié dans le cas du mobile.
# </strong>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/PythonLycee/PyLyc/master/img/Mobile_centre.png" style="width:250px; float: right;"/>
#
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
# <ul>
#     <li><strong>Question 1.10. </strong><br>Visionner à nouveau la vidéo proposée et préciser si nous aurions obtenu les mêmes résultats en pointant un autre point sur le bord du mobile (voir illustration ci-contre).</li>
# </ul>
# </BLOCKQUOTE>

# %% [raw]
# Écrire votre réponse ici (question 1.10)

# %% [markdown]
# <strong style="color:red">1.10.<br><br>
# On observe une légère rotation du mobile lors du mouvement. Si on ne pointe pas le centre du mobile, la trajectoire ne sera pas rectiligne. Le principe d'inertie s'applique au centre de l'objet.
# </strong>

# %% [markdown]
# <figure style="float: right; padding-left: 20px;">
#     <video controls src="https://raw.githubusercontent.com/PythonLycee/PyLyc/master/video/Chute_balle.mp4" width="150" height="270" />
# </figure>
#
# <span id="2"></span>
# <h3 style="color:#1333A8; font-size:28px">2. Chute d'une balle</h3>
#
# <br><br><br>
# On se propose d'étudier la chute verticale d'une balle.
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
# <ul>
#     <li><strong>Question 2.1. </strong><br><br>
# À l'aide de la vidéo ci-contre, préciser le système et le référentiel de l'étude.
#     </li>
# </ul>
# </BLOCKQUOTE>

# %% [raw]
# Écrire votre réponse ici (question 2.1)

# %% [markdown]
# <strong style="color:red">2.1.<br><br>
# Le système étudié est une balle. On observe le mouvement dans le référentiel terrestre.
# </strong>

# %% [markdown]
# <table style="border-collapse:collapse;border-spacing:0;table-layout: fixed; width: 543px" class="tg"><colgroup><col style="width: 119px"><col style="width: 106px"><col style="width: 106px"><col style="width: 106px"><col style="width: 106px"></colgroup><thead><tr><th style="background-color:#dae8fc;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">Balle n°</th><th style="background-color:#ecf4ff;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">1</th><th style="background-color:#ecf4ff;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">2</th><th style="background-color:#ecf4ff;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">3</th><th style="background-color:#ecf4ff;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">4</th></tr></thead><tbody><tr><td style="background-color:#dae8fc;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">Visuel</td><td style="background-color:#ecf4ff;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal"><img src="https://raw.githubusercontent.com/PythonLycee/PyLyc/master/img/Balles/Balle1.png"></td><td style="background-color:#ecf4ff;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal"><img src="https://raw.githubusercontent.com/PythonLycee/PyLyc/master/img/Balles/Balle3.png"></td><td style="background-color:#ecf4ff;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal"><img src="https://raw.githubusercontent.com/PythonLycee/PyLyc/master/img/Balles/Balle4.png"></td><td style="background-color:#ecf4ff;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal"><img src="https://raw.githubusercontent.com/PythonLycee/PyLyc/master/img/Balles/Balle5.png"></td></tr></tbody></table>
# <br>
# On dispose de plusieurs balles de masses et diamètres différents.<br>
# On lâche les balles sans vitesses initiales et on considère que leurs mouvements sont des chutes libres.<br>
# Lors d'une chute libre, le système n'est soumis qu'à une seule force : le poids.
# <br>
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
# <ul>
#     <li><strong>Question 2.2. </strong><br><br>
# <strong>a.</strong> Dans la cellule ci-dessous, choisir une valeur de 1 à 4 pour la variable <mark style="font-family: Consolas; background-color:#CAD4FC;">balle</mark>.<br>
# $\quad$Exécuter ensuite cette cellule.<br>
#     </li>
# </ul>
# </BLOCKQUOTE>

# %%
# Choisir une valeur pour la balle (de 1 à 4) puis exécuter cette cellule (SHIFT+Entrée)

balle = 1

ref_iframe={
            1:"""<iframe scrolling="no" title="Chute_balle_1" src="https://www.geogebra.org/material/iframe/id/xtnvvpyz/width/894/height/655/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" width="890px" height="660px" style="border:0px;"> </iframe>""",
            2:"""<iframe scrolling="no" title="Chute_balle_2" src="https://www.geogebra.org/material/iframe/id/gy4qeznf/width/904/height/677/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" width="890px" height="660px" style="border:0px;"> </iframe>""",
            3:"""<iframe scrolling="no" title="Chute_balle_3" src="https://www.geogebra.org/material/iframe/id/vcw2qpab/width/875/height/660/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" width="890px" height="660px" style="border:0px;"> </iframe>""",
            4:"""<iframe scrolling="no" title="Chute_balle_4" src="https://www.geogebra.org/material/iframe/id/dyawbfxx/width/872/height/635/border/888888/sfsb/true/smb/false/stb/false/stbh/false/ai/false/asb/false/sri/false/rc/false/ld/false/sdz/false/ctl/false" width="890px" height="660px" style="border:0px;"> </iframe>""" 
            }
from IPython.display import HTML ; HTML(ref_iframe[balle])

# %% [markdown]
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
# <ul>
# <strong>b.</strong> Nommer la ou les force(s) négligée(s) en première approximation lors d'une chute libre.<br><br>
# <strong>c.</strong> Calculer l'intensité du poids en vous servant des données fournies par l'expérience.<br><br>
# <strong>d.</strong> Vérifier par un calcul que la poussée d'Archimède est négligeable dans le cas étudié.<br>
#         <BLOCKQUOTE style="background-color:#EFF2FE;">
#         Données :
#         <ul>
#             <li>Poussée d'archimède : $\Pi_A=\rho_\text{fluide}\times \text{V}_{\text{fluide déplacé}}\times g$ où :
#                 <ul>
#                     <li>$\rho_\text{fluide}$ correspond à la masse volumique du fluide dans lequel l'objet est immergé, exprimé en $\text{kg}\cdot\text{m}^{-3}$ ;</li>
#                     <li>$g$ correspond à l'intensité de la pesanteur.</li>
#                 </ul>
#             </li>
#             <li>Masse volumique de l'air : $\rho_{\text{air}}=1,3 \; \text{kg}\cdot\text{m}^{-3}$</li>
#             <li>Intensité de la pesanteur : $g=9,81 \; \text{N}\cdot\text{kg}^{-1}$</li>
#         </ul>
#         <br>
#        <details>
#     <summary style="cursor: pointer; background:#EFF2FE;">Aide :<br>$\quad\;$Si nécessaire, <strong>cliquer ici</strong> pour un rappel de la formule permettant de calculer le volume d'une boule.</summary>
#     <BLOCKQUOTE style="background-color:#CED6F7">
#     <figure style="float: right;">
# <img src="https://raw.githubusercontent.com/PythonLycee/PyLyc/master/img/illu_boule_rayon.png" />
#     </figure>
#         Le volume d'une boule exprimé en $\text{m}^3$ vaut :<br>
#         $\displaystyle \text{V}_\text{boule}= \frac{4}{3}\pi r^3 $<br>
#      où $r$ est le rayon de cette boule, exprimé en $\text{m}$.
#            </BLOCKQUOTE>
# </details>
# </BLOCKQUOTE>
# <figure style="float: right; padding-left: 20px; padding-right: 20px; background-color:#FFFFFF"><br>
# <img src="https://raw.githubusercontent.com/PythonLycee/PyLyc/master/img/Schema_balle.gif" style="width:50px;"/><br>
#     </figure>
#     <strong>e.</strong> Représenter sur un schéma la force s'exerçant sur la balle.
# <br><br>
# <strong>f.</strong> Suivre les instructions pour effectuer un pointage du centre de la balle choisie, lors de sa chute.<br><br>Note : on néglige les variations horizontales de la balle, et on étudie donc uniquement les ordonnées des positions successives de la balle.
# </ul>
# </BLOCKQUOTE>

# %% [raw]
# Écrire vos réponses ici : (questions 2.2.b-c-d)

# %% [markdown]
# <strong style="color:red">2.2.<br><br>
# b. En première approximation, on fait l'hypothèse que les frottements de l'air sont négligeables car la vitesse est modérée et car la plupart des balles sont lisses.<br><br>
# c. $\text{P} = \text{m}\times \text{g}$ avec $\text{m}$ la masse en kg et $\text{g}$ l'intensité de la pesanteur.
# Les résultats sont consignés dans le tableau ci-dessous, en fonction de la balle choisie.
# <table style="border-collapse:collapse;border-spacing:0;table-layout: fixed; width: 690px" class="tg"><colgroup><col style="width: 136px"><col style="width: 145px"><col style="width: 146px"><col style="width: 263px"></colgroup><thead><tr><th style="border-color:#000000;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:normal;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal"></th><th style="background-color:#ffccc9;border-color:#000000;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:left;vertical-align:top;word-break:normal">Question 2.2.c</th><th style="background-color:#ffccc9;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal" colspan="2">Question 2.2.d</th></tr></thead><tbody><tr><td style="background-color:#fd6864;border-color:#000000;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">Balle n°</td><td style="background-color:#fd6864;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">Poids $\text{P}$ en $\text{N}$</td><td style="background-color:#fd6864;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">Diamètre&lt;br&gt; en cm</td><td style="background-color:#fd6864;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">Poussée d'Archimède $\Pi_A$ en $\text{N}$<br></td></tr><tr><td style="background-color:#ffccc9;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">1</td><td style="background-color:#ffccc9;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">$1,2$</td><td style="background-color:#ffccc9;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">$8,2$</td><td style="background-color:#ffccc9;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">$3,7\cdot 10^{-6}$</td></tr><tr><td style="background-color:#ffccc9;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">2</td><td style="background-color:#ffccc9;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">$0,55$</td><td style="background-color:#ffccc9;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">$7,5$</td><td style="background-color:#ffccc9;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">$2,8\cdot 10^{-6}$</td></tr><tr><td style="background-color:#ffccc9;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">3</td><td style="background-color:#ffccc9;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">$0,13$</td><td style="background-color:#ffccc9;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">$4,4$</td><td style="background-color:#ffccc9;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">$5,7\cdot 10^{-7}$</td></tr><tr><td style="background-color:#ffccc9;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;font-weight:bold;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">4</td><td style="background-color:#ffccc9;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">$0,17$</td><td style="background-color:#ffccc9;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">$3,9$</td><td style="background-color:#ffccc9;border-color:inherit;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;overflow:hidden;padding:10px 5px;text-align:center;vertical-align:top;word-break:normal">$4,0\cdot 10^{-7}$</td></tr></tbody></table>
# <br>d. Les résultats sont consignés dans le tableaux ci-dessus, en fonction de la balle choisie.
# <br><br>
# On constate que la poussée d'Archimède exercée sur les balles est très faible (en moyenne un million de fois plus faible que le poids). Elle est négligeable.
# <br><br>
# e.
# <br><img src="https://raw.githubusercontent.com/PythonLycee/PyLyc/master/img/balle_corr_schema.png" style="float:left; "/>
# </strong>

# %% [markdown]
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
# <ul>
#     <li><strong>Question 2.3. </strong><br>À l'aide du pointage précédent, compléter la liste <mark style="font-family: Consolas; background-color:#CAD4FC;">yB</mark> suivante avec les ordonnées des points $\text{M}_1$, $\text{M}_2$, $\text{M}_3$... et exécuter ensuite cette cellule pour stocker cette liste en mémoire.
# </li>
# </ul>
# </BLOCKQUOTE>

# %%
# liste des ordonnées de la balle

# Valeurs pour la balle 1
yB = [ 106 , 102.1 , 98.4 , 93.2 , 87 , 79.2 , 69.9 , 60.7 , 48.6 , 36.8 , 24 , 10.5 ]

# Valeurs pour la balle 2   
#yB = [ 103.3 , 99.8 , 94.9 , 88.9 , 81.4 , 73.4 , 63.7 , 53.7 , 42.4 , 30.6 , 17.8 , 4.9 ] # liste des ordonnées de la balle

# Valeurs pour la balle 3
#yB = [ 103.3 , 100.7 , 97.1 , 92 , 86.2 , 78.7 , 70.3 , 60.8 , 50.6 , 39.7 , 28.5 , 14.9 ] # liste des ordonnées de la balle

# Valeurs pour la balle 4
#yB = [ 104.6 , 101.1 , 96.3 , 90.3 , 83.3 , 75.6 , 66.1 , 56.4 , 45.5 , 33.7 , 20.9 , 7.8 ] # liste des ordonnées de la balle

# intervalle de temps entre deux prises de vue (exprimé en s)
Dt = 1/30

# %% [markdown]
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
# <ul>
#     <li><strong>Question 2.4. </strong><br>
# Exécuter la cellule suivante, qui calcule les distances $\text{M}_i\text{M}_{i+1}$.<br>
# À partir des résultats obtenus, indiquer quelle caractéristique du mouvement de la balle est mise en évidence.
#     </li></ul>
# </BLOCKQUOTE>

# %%
# Exécuter cette cellule (SHIFT+Entrée)

def diff_ordonnees(y):
    return [ round (abs( y[i+1]-y[i] ) ,1) for i in range(len(y)-1) ]

diff_ordonnees(yB)

# %% [raw]
# Écrire votre réponse ici (question 2.4)

# %% [markdown]
# <strong style="color:red">2.4.<br><br>
# La distance entre les points augmente au cours du mouvement. Le mouvement semble accéléré.
# </strong>

# %% [markdown]
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
# <ul>
#     <li><strong>Question 2.5. </strong><br><strong>a.</strong> En s'inspirant des syntaxes fournies dans la question 1.5, créer une liste <mark style="font-family: Consolas; background-color:#CAD4FC;">vyB</mark> contenant les ordonnées des vecteurs vitesse pour chaque position $\text{M}_1$, $\text{M}_2$...<br>
#         <strong>b.</strong> Valider la cellule pour obtenir les valeurs.<br>
#         <strong>c.</strong> Observer les valeurs obtenues puis décrire le mouvement de la balle.</li>
# </ul>
# </BLOCKQUOTE>

# %%
# liste des ordonnées des vecteurs vitesse
vyB = [ round ( (yB[k+1]-yB[k])/Dt ,1) for k in range(len(yB)-1) ] 

vyB

# %% [raw]
# Écrire votre réponse ici (question 2.5.c)

# %% [markdown]
# <strong style="color:red">2.5.<br><br>
# c.
# Le mouvement est rectiligne (pas ou peu de variation horizontale). La distance entre les points augmente au cours du mouvement. La balle parcourt une distance de plus en plus grande pendant l'intervalle de temps $\frac{1}{30}$ s. Ainsi, le mouvement est accéléré.
#
# </strong>

# %% [markdown]
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
# <ul>
#     <li><strong>Question 2.6. </strong><br>Exécuter la cellule ci-dessous pour obtenir un graphique avec le tracé des <span style="color: #0000FF">vecteurs vitesse</span> pour le <span style="color: #FF0000">pointage</span> effectué.
#         </li></ul>
# </BLOCKQUOTE>

# %%
# Exécuter cette cellule (SHIFT+Entrée)
Graph_Pointage(x=[0 for _ in range(len(yB))],y=yB,vx=[0 for _ in range(len(vyB))],vy=vyB,zoom_v=50,titre="Trajectoire de la balle",nb_fig=2)

# %% [markdown]
# <BLOCKQUOTE style="background-color:#DFE6FF; color:#031E7F;">
#     <ul>
#         <li><strong>Question 2.7. </strong><br>Indiquer en justifiant si le principe d’inertie est vérifié dans le cas de la chute de la balle.</li></ul>
# </BLOCKQUOTE>

# %% [raw]
# Écrire votre réponse ici (question 2.7)

# %% [markdown]
# <strong style="color:red">2.7.<br><br>
# Les forces qui s'exercent sur la balle ne se compensent pas puisqu'il n'y a qu'une seule force qui s'exerce sur la balle. Le mouvement de la balle est rectiligne mais pas uniforme. Dans ce cas également, le principe d'inertie est vérifié (cela correspond à la contraposée du principe d'inertie).
# </strong>

# %% [markdown]
# <i>© Copyright Franck CHEVRIER 2019-2023 https://www.python-lycee.com.</i><br>
# <i>Activité réalisée en collaboration avec Carole BOURGON.</i><br>
# <i>Les activités partagées sur <a href="https://capytale2.ac-paris.fr/web/accueil"><strong>Capytale</strong></a> sont sous licence <a href="https://creativecommons.org/licenses/by-sa/3.0/fr/">Creative Commons</a>.</i>
# <br><br>
# <span style="font-size:8px">Dernière modification de l'activité : Juillet 2023</span>
