# %% [markdown]
# CHEVRIER - 2021/2022 - SNT
#
# <BLOCKQUOTE style='background-color:#FFEEEE; color:red;'>
# <strong>AVERTISSEMENT :</strong><br>
# Ce document est un devoir noté.<br>
# Il faut double-cliquer sur les cellules pour saisir les réponses.<br>
# <br>
# !!!<u>Attention</u>!!!<br>
#     <strong>Enregistrez</strong> régulièrement votre travail <strong>en cliquant sur l'icone en haut à gauche, en forme de disquette.</strong><br>
# Le message "Les informations ont bien été enregistrées dans Capytale." doit alors apparaître.
# </BLOCKQUOTE>

# %% [markdown]
# # Partie I. Découvrons l'histoire d'Internet

# %% [markdown]
# Visionner la vidéo ci-dessous puis répondre aux questions.<br><br>

# %%
from IPython.display import HTML 
HTML("""<iframe width="560" height="315" src="https://www.youtube.com/embed/w-JTxfObL0E" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>""")
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/w-JTxfObL0E" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## 1. Arpanet
#
# <strong>a. En quelle année apparaît le réseau Arpanet, ancètre d'Internet ? À quel besoin Arpanet répondait-il ?</strong>

# %% [markdown]
# (double cliquer sur cette zone pour saisir votre réponse)

# %% [markdown]
# <strong>b. Où étaient connectés les premiers ordinateurs en réseau sur Arpanet ?</strong>

# %% [markdown]
# (double cliquer sur cette zone pour saisir votre réponse)

# %% [markdown]
# <strong>c. À quelle période Arpanet a-t-il disparu ?</strong>

# %% [markdown]
# (double cliquer sur cette zone pour saisir votre réponse)

# %% [markdown]
# ## 2. Protocole TCP, naissance d’Internet
#
# <strong>a. En quelle année le protocole de communication TCP apparait-il ? </strong>

# %% [markdown]
# (double cliquer sur cette zone pour saisir votre réponse)

# %% [markdown]
# <strong>b. En quelle année est-il généralisé à l’ensemble des communications ?</strong>

# %% [markdown]
# (double cliquer sur cette zone pour saisir votre réponse)

# %% [markdown]
# <strong>c. À partir de quelle période un particulier pouvait-il utiliser le réseau internet ?</strong>

# %% [markdown]
# (double cliquer sur cette zone pour saisir votre réponse)

# %% [markdown]
# # Partie II. Découvrons le Web

# %% [markdown]
# Visionner la vidéo ci-dessous puis répondre aux questions.<br><br>

# %%
from IPython.display import HTML 
HTML("""<iframe width="560" height="315" src="https://www.youtube.com/embed/6NypXJekqD4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>""")
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/6NypXJekqD4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# <strong>1. Quelle sont les particularités d’un document hypertexte par rapport à un texte ?</strong>

# %% [markdown]
# (double cliquer sur cette zone pour saisir votre réponse)

# %% [markdown]
# <strong>2. En quelle année des documents hypertextes font-ils leur apparition sur Internet ?</strong>

# %% [markdown]
# (double cliquer sur cette zone pour saisir votre réponse)

# %% [markdown]
# <strong>3. Que signifie l’abréviation www ? que désigne-t-elle ?</strong>

# %% [markdown]
# (double cliquer sur cette zone pour saisir votre réponse)

# %% [markdown]
# <strong>4. Quel type de logiciel permet d’ouvrir des documents hypertexte ?</strong>

# %% [markdown]
# (double cliquer sur cette zone pour saisir votre réponse)

# %% [markdown]
# <strong>5. Combien existe-t-il aujourd’hui de sites web hébergeant des documents hypertextes ?</strong>

# %% [markdown]
# (double cliquer sur cette zone pour saisir votre réponse)

# %% [markdown]
# <BLOCKQUOTE style='background-color:#FFEEEE; color:red;'>
# Fin du devoir.<br>
# !!!<u>Attention</u>!!!<br>
#     <strong>N'oubliez pas d'Enregistrer votre travail en cliquant sur l'icone en haut à gauche, en forme de disquette.</strong><br>
# Le message "Les informations ont bien été enregistrées dans Capytale." doit alors apparaître.
# </BLOCKQUOTE>
